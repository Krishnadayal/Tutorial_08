# %% [markdown]
# <a href="https://colab.research.google.com/github/Krishnadayal/Tutorial_08/blob/main/Week_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Task 1
df = pd.read_csv("/content/diabetes.csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Task 2
df["BloodPressure"].median()
# Out:
# 72.0

# %%
# Task 3
df["Outcome"].unique()
# Out:
# array([1, 0])

# %%
df["Outcome"].value_counts()*100/len(df)
# Out:
# Outcome
# 0    65.104167
# 1    34.895833
# Name: count, dtype: float64

# %%
# Task 4
x = df.iloc[:,:-1].values
y = df.iloc[:,-1].values

# %%
# Task 5
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1, stratify=y)

# %%
# Task 6
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=1, stratify=y)

# %%
# Task 7
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

clf = DecisionTreeClassifier(random_state=1)
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)

# Print accuracy
print(f"Decision Tree Classifier Accuracy: {accuracy:.4f}")
# Out:
# Decision Tree Classifier Accuracy: 0.7240

# %%
# Task 8
train_accuracy = accuracy_score(y_train, clf.predict(x_train))
test_accuracy = accuracy_score(y_test, y_pred)

print(f"Training Accuracy: {train_accuracy:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# Training Accuracy: 1.0000
# Test Accuracy: 0.7240

# %%
# Task 9

# %%
# Task 10
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No Diabetes (0)', 'Diabetes (1)'], yticklabels=['No Diabetes (0)', 'Diabetes (1)'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.83      0.80       125
#            1       0.62      0.52      0.57        67
#
#     accuracy                           0.72       192
#    macro avg       0.69      0.68      0.68       192
# weighted avg       0.72      0.72      0.72       192

# %%
# Task 11
from sklearn import tree
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(10, 7), dpi=300)
tree.plot_tree(clf)
plt.show()

# %%
# Task 12

# %%
# Task 13
from sklearn.neighbors import KNeighborsClassifier
knn_clf = KNeighborsClassifier(n_neighbors=4)
knn_clf.fit(x_train, y_train)

knn_y_pred = knn_clf.predict(x_test)

knn_cm = confusion_matrix(y_test, knn_y_pred)

print("K-Nearest Neighbors Classifier Performance:")
print(classification_report(y_test, knn_y_pred))

plt.figure(figsize=(5,4))
sns.heatmap(knn_cm, annot=True, fmt='d', cmap='Greens', xticklabels=['No Diabetes (0)', 'Diabetes (1)'], yticklabels=['No Diabetes (0)', 'Diabetes (1)'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('KNN (4 Neighbors) Confusion Matrix')
plt.show()
# Out:
# K-Nearest Neighbors Classifier Performance:
#               precision    recall  f1-score   support
#
#            0       0.71      0.85      0.77       125
#            1       0.55      0.34      0.42        67
#
#     accuracy                           0.67       192
#    macro avg       0.63      0.60      0.60       192
# weighted avg       0.65      0.67      0.65       192

# %%
# Task 14
df2 = pd.read_csv("/content/pm25_2016_2020.csv")
df2.head()
# Out:
#    Unnamed: 0 date_local  latitude_x  longitude_x  elevation  tavg  tmin  \
# 0           0  6/15/2017   39.024265   -95.711275      280.0   NaN   NaN
# 1           1  6/18/2017   39.024265   -95.711275      280.0   NaN   NaN
# 2           2  6/21/2017   39.024265   -95.711275      280.0   NaN   NaN
# 3           3  6/24/2017   39.024265   -95.711275      280.0   NaN   NaN
# 4           4  6/30/2017   39.024265   -95.711275      280.0   NaN   NaN
#
#    tmax  prcp  snow  wdir  wspd  wpgt  pres  tsun  arithmetic_mean_a  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN                8.6
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN                3.4
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN                6.6
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN                5.1
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN                5.0
#
#    arithmetic_mean_b
# 0                9.2
# 1                3.9
# 2                6.7
# ...

# %%
# Task 15
x = df2[['latitude_x', 'longitude_x']]
x
# Out:
#        latitude_x  longitude_x
# 0       39.024265   -95.711275
# 1       39.024265   -95.711275
# 2       39.024265   -95.711275
# 3       39.024265   -95.711275
# 4       39.024265   -95.711275
# ...           ...          ...
# 99995   42.978248  -112.455813
# 99996   42.978248  -112.455813
# 99997   42.978248  -112.455813
# 99998   42.978248  -112.455813
# 99999   42.978248  -112.455813
#
# [100000 rows x 2 columns]

# %%
# Task 16
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=6)
x["Clusters"] = kmeans.fit_predict(x)
x["Clusters"] = x["Clusters"].astype("category")
x
# Out:
# <ipython-input-18-3d17b8022967>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x["Clusters"] = kmeans.fit_predict(x)
# <ipython-input-18-3d17b8022967>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x["Clusters"] = x["Clusters"].astype("category")
#        latitude_x  longitude_x Clusters
# 0       39.024265   -95.711275        3
# 1       39.024265   -95.711275        3
# 2       39.024265   -95.711275        3
# 3       39.024265   -95.711275        3
# ...

# %%
# Task 17
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5)
x["Clusters"] = kmeans.fit_predict(x)
x["Clusters"] = x["Clusters"].astype("category")
x
# Out:
# <ipython-input-19-d187a0f353d3>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x["Clusters"] = kmeans.fit_predict(x)
# <ipython-input-19-d187a0f353d3>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x["Clusters"] = x["Clusters"].astype("category")
#        latitude_x  longitude_x Clusters
# 0       39.024265   -95.711275        3
# 1       39.024265   -95.711275        3
# 2       39.024265   -95.711275        3
# 3       39.024265   -95.711275        3
# ...

# %%
# Task 18
import matplotlib
matplotlib.rcParams['figure.figsize'] = (12,8)
sns.relplot(x='latitude_x',y='longitude_x',hue='Clusters',data=x,palette='viridis')
